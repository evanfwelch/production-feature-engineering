# %%
import dask
import json

# %%
PURCHASE_DATA = './DATA/RAW/purchases/purchase*.json'

# %%
# !ls -lsrt ./DATA/RAW/purchases
# Out:
# total 56
#  8 -rw-r--r--  1 evanwelch  staff  3195 Mar 14 12:09 purchase-0000.json
# 16 -rw-r--r--  1 evanwelch  staff  6122 Mar 14 12:09 purchase-0001.json
# 16 -rw-r--r--  1 evanwelch  staff  5393 Mar 14 12:09 purchase-0002.json
#  8 -rw-r--r--  1 evanwelch  staff  2442 Mar 14 12:09 purchase-0003.json
#  8 -rw-r--r--  1 evanwelch  staff   308 Mar 14 12:09 manifest.json

# %%
import dask.bag as db

# %%
b = db.read_text(PURCHASE_DATA).map(json.loads).flatten().flatten()

# %%
b.filter
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-121-443512a995c5> in <module>()
# ----> 1 b.get
#
# AttributeError: 'Bag' object has no attribute 'get'

# %%
for bb in b:
    print(bb.keys())
# Out:
# dict_keys(['_id', 'merchant_id', 'medium', 'purchase_date', 'amount', 'status', 'type', 'payer_id'])
# dict_keys(['_id', 'merchant_id', 'medium', 'purchase_date', 'amount', 'status', 'type', 'payer_id'])
# dict_keys(['_id', 'merchant_id', 'medium', 'purchase_date', 'amount', 'status', 'type', 'payer_id'])
# dict_keys(['_id', 'merchant_id', 'medium', 'purchase_date', 'amount', 'status', 'type', 'payer_id'])
# dict_keys(['_id', 'merchant_id', 'medium', 'purchase_date', 'amount', 'status', 'type', 'payer_id'])
# dict_keys(['_id', 'merchant_id', 'medium', 'purchase_date', 'amount', 'status', 'type', 'payer_id'])
# dict_keys(['_id', 'merchant_id', 'medium', 'purchase_date', 'amount', 'status', 'type', 'payer_id'])
# dict_keys(['_id', 'merchant_id', 'medium', 'purchase_date', 'amount', 'status', 'type', 'payer_id'])
# dict_keys(['_id', 'merchant_id', 'medium', 'purchase_date', 'amount', 'status', 'type', 'payer_id'])
# ...

# %%
bb.flatten().count().compute()
# Out:
# 70

# %%
help(bb)
# Out:
# Help on Bag in module dask.bag.core object:
#
# class Bag(dask.base.Base)
#  |  Parallel collection of Python objects
#  |
#  |  Examples
#  |  --------
#  |  Create Bag from sequence
#  |
#  |  >>> import dask.bag as db
#  |  >>> b = db.from_sequence(range(5))
#  |  >>> list(b.filter(lambda x: x % 2 == 0).map(lambda x: x * 10))  # doctest: +SKIP
#  |  [0, 20, 40]
#  |
#  |  Create Bag from filename or globstring of filenames
#  |
#  |  >>> b = db.read_text('/path/to/mydata.*.json.gz').map(json.loads)  # doctest: +SKIP
#  |
#  |  Create manually (expert use)
#  |
#  |  >>> dsk = {('x', 0): (range, 5),
#  |  ...        ('x', 1): (range, 5),
#  |  ...        ('x', 2): (range, 5)}
#  |  >>> b = Bag(dsk, 'x', npartitions=3)
#  |
#  |  >>> sorted(b.map(lambda x: x * 10))  # doctest: +SKIP
#  |  [0, 0, 0, 10, 10, 10, 20, 20, 20, 30, 30, 30, 40, 40, 40]
#  |
#  |  >>> int(b.fold(lambda x, y: x + y))  # doctest: +SKIP
#  |  30
#  |
#  |  Method resolution order:
#  |      Bag
# ...

# %%
bb.to_dataframe(meta={'_id':str}).head()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-91-a728f40fdd6f> in <module>()
# ----> 1 bb.to_dataframe(meta={'_id':str}).head()
#
# ~/PROJECTS/production-feature-engineering/env/lib/python3.6/site-packages/dask/dataframe/core.py in head(self, n, npartitions, compute)
#     873
#     874         if compute:
# --> 875             result = result.compute()
#     876         return result
#     877
#
# ~/PROJECTS/production-feature-engineering/env/lib/python3.6/site-packages/dask/base.py in compute(self, **kwargs)
#     141         dask.base.compute
#     142         """
# --> 143         (result,) = compute(self, traverse=False, **kwargs)
#     144         return result
#     145
#
# ~/PROJECTS/production-feature-engineering/env/lib/python3.6/site-packages/dask/base.py in compute(*args, **kwargs)
# ...

# %%
bb[0][1]
# Out:
# {'_id': '5aa96e42f0cec56abfa3dd23',
#  'amount': 266.2592863796192,
#  'medium': 'balance',
#  'merchant_id': '57cf75cea73e494d8675f1c2',
#  'payer_id': '5aa96e3cf0cec56abfa3dd10',
#  'purchase_date': '2017-12-03',
#  'status': 'cancelled',
#  'type': 'merchant'}

# %%
for bb in b:
    print(len(bb[0]))
# Out:
# 1
# 3
# 6
# 10

# %%
b.compute()
# Out:
# [[[{'_id': '5aa96e43f0cec56abfa3dd25',
#     'amount': 132.69078191085438,
#     'medium': 'balance',
#     'merchant_id': '57cf75cea73e494d8675f4e2',
#     'payer_id': '5aa96e3af0cec56abfa3dd0e',
#     'purchase_date': '2017-12-06',
#     'status': 'cancelled',
#     'type': 'merchant'}],
#   [],
#   [{'_id': '5aa96e42f0cec56abfa3dd23',
#     'amount': 266.2592863796192,
#     'medium': 'balance',
#     'merchant_id': '57cf75cea73e494d8675f1c2',
#     'payer_id': '5aa96e3cf0cec56abfa3dd10',
#     'purchase_date': '2017-12-03',
#     'status': 'cancelled',
#     'type': 'merchant'},
#    {'_id': '5aa96e43f0cec56abfa3dd24',
#     'amount': 47.42988464504788,
#     'medium': 'balance',
#     'merchant_id': '57cf75cea73e494d8675f0d6',
#     'payer_id': '5aa96e3cf0cec56abfa3dd10',
#     'purchase_date': '2017-12-05',
#     'status': 'cancelled',
#     'type': 'merchant'}],
#   [{'_id': '5aa96e43f0cec56abfa3dd26',
#     'amount': 34.61688221433864,
#     'medium': 'balance',
# ...

# %%
a = [[[{'_id': '5aa96e43f0cec56abfa3dd25',
    'amount': 132.69078191085438,
    'medium': 'balance',
    'merchant_id': '57cf75cea73e494d8675f4e2',
    'payer_id': '5aa96e3af0cec56abfa3dd0e',
    'purchase_date': '2017-12-06',
    'status': 'cancelled',
    'type': 'merchant'}],
  [],
  [{'_id': '5aa96e42f0cec56abfa3dd23',
    'amount': 266.2592863796192,
    'medium': 'balance',
    'merchant_id': '57cf75cea73e494d8675f1c2',
    'payer_id': '5aa96e3cf0cec56abfa3dd10',
    'purchase_date': '2017-12-03',
    'status': 'cancelled',
    'type': 'merchant'},
   {'_id': '5aa96e43f0cec56abfa3dd24',
    'amount': 47.42988464504788,
    'medium': 'balance',
    'merchant_id': '57cf75cea73e494d8675f0d6',
    'payer_id': '5aa96e3cf0cec56abfa3dd10',
    'purchase_date': '2017-12-05',
    'status': 'cancelled',
    'type': 'merchant'}],
  [{'_id': '5aa96e43f0cec56abfa3dd26',
    'amount': 34.61688221433864,
    'medium': 'balance',
    'merchant_id': '57cf75cea73e494d8675f54a',
    'payer_id': '5aa96e3cf0cec56abfa3dd11',
    'purchase_date': '2017-12-06',
    'status': 'cancelled',
    'type': 'merchant'},
   {'_id': '5aa96e43f0cec56abfa3dd27',
    'amount': 386.32945590959645,
    'medium': 'balance',
    'merchant_id': '57cf75cea73e494d8675f392',
    'payer_id': '5aa96e3cf0cec56abfa3dd11',
    'purchase_date': '2017-12-10',
    'status': 'cancelled',
    'type': 'merchant'}],
  [{'_id': '5aa96e44f0cec56abfa3dd29',
    'amount': 16.538316217061542,
    'medium': 'balance',
    'merchant_id': '59fe4e5cb390353c953a1d98',
    'payer_id': '5aa96e3df0cec56abfa3dd12',
    'purchase_date': '2017-12-02',
    'status': 'cancelled',
    'type': 'merchant'},
   {'_id': '5aa96e44f0cec56abfa3dd2a',
    'amount': 12.878661654244095,
    'medium': 'balance',
    'merchant_id': '57cf75cea73e494d8675

    'medium': 'balance',
    'merchant_id': '57cf75cea73e494d8675f5c8',
    'payer_id': '5aa96e3ff0cec56abfa3dd20',
    'purchase_date': '2017-12-10',
    'status': 'cancelled',
    'type': 'merchant'}],
  []],
 [[{'_id': '5aa96e4ff0cec56abfa3dd5f',
    'amount': 23.050498342314256,
    'medium': 'balance',
    'merchant_id': '57cf75cea73e494d8675ef88',
    'payer_id': '5aa96e3ff0cec56abfa3dd22',
    'purchase_date': '2017-12-01',
    'status': 'cancelled',
    'type': 'merchant'},
   {'_id': '5aa96e50f0cec56abfa3dd60',
    'amount': 101.13480153536517,
    'medium': 'balance',
    'merchant_id': '57cf75cfa73e494d8675f8bc',
    'payer_id': '5aa96e3ff0cec56abfa3dd22',
    'purchase_date': '2017-12-02',
    'status': 'cancelled',
    'type': 'merchant'},
   {'_id': '5aa96e50f0cec56abfa3dd61',
    'amount': 45.81492850067819,
    'medium': 'balance',
    'merchant_id': '57cf75cea73e494d8675f19a',
    'payer_id': '5aa96e3ff0cec56abfa3dd22',
    'purchase_date': '2017-12-03',
    'status': 'cancelled',
    'type': 'merchant'},
   {'_id': '5aa96e50f0cec56abfa3dd62',
    'amount': 115.23444771422162,
    'medium': 'balance',
    'merchant_id': '58a91af31756fc834d9055ba',
    'payer_id': '5aa96e3ff0cec56abfa3dd22',
    'purchase_date': '2017-12-04',
    'status': 'cancelled',
    'type': 'merchant'},
   {'_id': '5aa96e50f0cec56abfa3dd63',
    'amount': 67.87378153469372,
    'medium': 'balance',
    'merchant_id': '58a8e5e91756fc834d9053de',
    'payer_id': '5aa96e3ff0cec56abfa3dd22',
    'purchase_date': '2017-12-05',
    'status': 'cancelled',
    'type': 'merchant'},
   {'_id': '5aa96e51f0cec56abfa3dd64',
    'amount': 41.59783373118243,
    'medium': 'balance',
    'merchant_id': '57cf75cfa73e494d8675f86d',
    'payer_id': '5aa96e3ff0cec56abfa3dd22',
    'purchase_date': '2017-12-06',
    'status': 'cancelled',
    'type': 'merchant'},
   {'_id': '5aa96e55f0cec56abfa3dd65',
    'amount': 98.07564168116,
    'medium': 'balance',
    'merchant_id': '57cf75cea73e494d8675f051',
    'payer_id': '5aa96e3ff0cec56abfa3dd22',
    'purchase_date': '2017-12-07',
    'status': 'cancelled',
    'type': 'merchant'},
   {'_id': '5aa96e55f0cec56abfa3dd66',
    'amount': 35.478094396329496,
    'medium': 'balance',
    'merchant_id': '57cf75cfa73e494d8675fa32',
    'payer_id': '5aa96e3ff0cec56abfa3dd22',
    'purchase_date': '2017-12-08',
    'status': 'cancelled',
    'type': 'merchant'},
   {'_id': '5aa96e55f0cec56abfa3dd67',
    'amount': 38.227698035246746,
    'medium': 'balance',
    'merchant_id': '58a8e5e91756fc834d9053de',
    'payer_id': '5aa96e3ff0cec56abfa3dd22',
    'purchase_date': '2017-12-09',
    'status': 'cancelled',
    'type': 'merchant'},
   {'_id': '5aa96e56f0cec56abfa3dd68',
    'amount': 84.549411643927,
    'medium': 'balance',
    'merchant_id': '57cf75cea73e494d8675f070',
    'payer_id': '5aa96e3ff0cec56abfa3dd22',
    'purchase_date': '2017-12-10',
    'status': 'cancelled',
    'type': 'merchant'}]]]

# %%
a[0][2]
# Out:
# [{'_id': '5aa96e42f0cec56abfa3dd23',
#   'amount': 266.2592863796192,
#   'medium': 'balance',
#   'merchant_id': '57cf75cea73e494d8675f1c2',
#   'payer_id': '5aa96e3cf0cec56abfa3dd10',
#   'purchase_date': '2017-12-03',
#   'status': 'cancelled',
#   'type': 'merchant'},
#  {'_id': '5aa96e43f0cec56abfa3dd24',
#   'amount': 47.42988464504788,
#   'medium': 'balance',
#   'merchant_id': '57cf75cea73e494d8675f0d6',
#   'payer_id': '5aa96e3cf0cec56abfa3dd10',
#   'purchase_date': '2017-12-05',
#   'status': 'cancelled',
#   'type': 'merchant'}]

# %%
map(a[0])
# Out:
# [[{'_id': '5aa96e43f0cec56abfa3dd25',
#    'amount': 132.69078191085438,
#    'medium': 'balance',
#    'merchant_id': '57cf75cea73e494d8675f4e2',
#    'payer_id': '5aa96e3af0cec56abfa3dd0e',
#    'purchase_date': '2017-12-06',
#    'status': 'cancelled',
#    'type': 'merchant'}],
#  [],
#  [{'_id': '5aa96e42f0cec56abfa3dd23',
#    'amount': 266.2592863796192,
#    'medium': 'balance',
#    'merchant_id': '57cf75cea73e494d8675f1c2',
#    'payer_id': '5aa96e3cf0cec56abfa3dd10',
#    'purchase_date': '2017-12-03',
#    'status': 'cancelled',
#    'type': 'merchant'},
#   {'_id': '5aa96e43f0cec56abfa3dd24',
#    'amount': 47.42988464504788,
#    'medium': 'balance',
#    'merchant_id': '57cf75cea73e494d8675f0d6',
#    'payer_id': '5aa96e3cf0cec56abfa3dd10',
#    'purchase_date': '2017-12-05',
#    'status': 'cancelled',
#    'type': 'merchant'}],
#  [{'_id': '5aa96e43f0cec56abfa3dd26',
#    'amount': 34.61688221433864,
#    'medium': 'balance',
# ...
